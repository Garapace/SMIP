# %% [markdown]
# # Лабораторная работа №1

# %% [markdown]
# ## Задание 1

# %% [markdown]
# 1) загружаем таблицу html

# %%
import pandas as pd

df = pd.read_html()
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_html()
#       4 df
#
# TypeError: read_html() missing 1 required positional argument: 'io'
